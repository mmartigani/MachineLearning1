# %%
import pandas as pd

# %%
#como se cargan los dataset

# %%
df =pd.read_csv("/content/diabetes_data_upload.csv")
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df1=pd.read_excel("/content/activaciones_samur_2024.xls")
df1
# Out:
#         Año    Mes Hora Solicitud Hora Intervención  \
# 0      2024  ENERO       00:03:49          00:06:39
# 1      2023  ENERO       00:05:55          00:20:38
# 2      2023  ENERO       00:05:55          00:20:38
# 3      2024  ENERO       00:16:34          00:21:20
# 4      2024  ENERO       00:17:12               NaN
# ...     ...    ...            ...               ...
# 35408  2024  MARZO       23:51:17               NaN
# 35409  2024  MARZO       23:57:12          00:06:59
# 35410  2024  MARZO       23:58:27          00:03:56
# 35411  2024  MARZO            NaN               NaN
# 35412  2024  MARZO            NaN               NaN
#
#                                               Código           Distrito  \
# 0                                            Heridas           CHAMBERI
# 1      Atención psicológica a Familiares y allegados      CIUDAD LINEAL
# 2                      Inconsciente sin filiar causa      CIUDAD LINEAL
# ...

# %%
#nan = not a number

# %%
#conversion de dataframe a un json
df2=pd.DataFrame([["a","b"],["c","d"]],
                  index=["row1", "row2"],
                 columns=["col1", "col2"])
df2
# Out:
#      col1 col2
# row1    a    b
# row2    c    d

# %%
json_string=df2.to_json(orient="split")
json_string
# Out:
# '{"columns":["col1","col2"],"index":["row1","row2"],"data":[["a","b"],["c","d"]]}'

# %%
json_string=df2.to_json(orient="records")
json_string
# Out:
# '[{"col1":"a","col2":"b"},{"col1":"c","col2":"d"}]'

# %%
#cargar de una cadena json a un dataframe
pd.read_json(json_string,orient="records")
# Out:
#   col1 col2
# 0    a    b
# 1    c    d

# %%
pd.read_json(json_string,orient="columns")
# Out:
#   col1 col2
# 0    a    b
# 1    c    d

# %%
sub_dict={"asignatura":"historia", "aula":["a1", "b2"]}
sub_dict
# Out:
# {'asignatura': 'historia', 'aula': ['a1', 'b2']}

# %%
import json

# %%
json.dumps(sub_dict)
# Out:
# '{"asignatura": "historia", "aula": ["a1", "b2"]}'

# %%
sub_dict2={"asignatura":"Matemática", "aula":["a1", "b2"]}
sub_dict2
# Out:
# {'asignatura': 'Matemática', 'aula': ['a1', 'b2']}

# %%
#evita que tenegamos errores con las comas y los acentos

# %%
json.dumps(sub_dict2, ensure_ascii=False)
# Out:
# '{"asignatura": "Matemática", "aula": ["a1", "b2"]}'

# %%
#cambiar un json a un dicionario
string1='{"asignatura":"historia" ,"aula":["a11", "b12"]}'
json.loads(string1)
# Out:
# {'asignatura': 'historia', 'aula': ['a11', 'b12']}
